# %%
import pandas as pd
import numpy as np
from utils import tokenizeAndRemoveStopWordsOrStemAndReturnVocabulary, getTrainingAndTestingData2, plot_wordclouds_per_class, display_results_table
from modelUtils import run_model2
from naive_bayes_custom import NaiveBayesCustom

# Load the datasets
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

y_train = df_train['label'].values
y_val = df_test['label'].values
num_classes = len(df_train['label'].unique())
num_samples = len(y_val)

print(f"Number of classes: {num_classes}")
print(f"Number of validation samples: {num_samples}")
# Out:
# Number of classes: 14
# Number of validation samples: 35000

# %%
# Question no 7

# ----------------------------
# (a) Random prediction baseline
expected_random_accuracy = 1 / num_classes
print(f"Expected Random Accuracy (analytical): {expected_random_accuracy*100:.2f}%")

# Simulation-based random prediction
random_pred = np.random.choice(num_classes, size=num_samples)
accuracy_random_sim = np.mean(random_pred == y_val)
print(f"Random Prediction Accuracy (simulation): {accuracy_random_sim*100:.2f}%")

# ----------------------------
# (b) Positive-class baseline (most frequent class in training)
unique_classes, counts = np.unique(y_train, return_counts=True)
most_common_class = unique_classes[np.argmax(counts)]
positive_pred = np.full_like(y_val, most_common_class)
accuracy_positive = np.mean(positive_pred == y_val)
print(f"Positive-Class Accuracy: {accuracy_positive*100:.2f}%")

# ----------------------------
# (c) Model improvement
accuracy_model = 0.9690  # replace with your model's test accuracy
improvement_random = accuracy_model - expected_random_accuracy
improvement_positive = accuracy_model - accuracy_positive

print(f"Improvement over random baseline: {improvement_random*100:.2f}%")
print(f"Improvement over positive-class baseline: {improvement_positive*100:.2f}%")
# Out:
# Expected Random Accuracy (analytical): 7.14%
# Random Prediction Accuracy (simulation): 7.21%
# Positive-Class Accuracy: 7.14%
# Improvement over random baseline: 89.76%
# Improvement over positive-class baseline: 89.76%

# %%
# Question 9
df_train.head()
# Out:
#    label                              title  \
# 0      3                          Ernie Cox
# 1     10                          Holosteum
# 2      9                Pestarella tyrrhena
# 3      1          MidSun Junior High School
# 4      6  St James' Church Wrightington Bar
#
#                                              content
# 0   Ernest Ernie Cox (February 17 1894 – February...
# 1   Holosteum is a genus of plants in the Pink fa...
# 2   Pestarella tyrrhena (formerly Callianassa tyr...
# 3   MidSun Junior High School is a Canadian middl...
# 4   St James' Church Wrightington Bar is in Churc...

# %%
df_train, vocabularyTitle = tokenizeAndRemoveStopWordsOrStemAndReturnVocabulary(df_train, "title", target_col = "Tokenized Title", remove_stop_words = False, with_stemming = False, window = [1,2])
df_test, _ = tokenizeAndRemoveStopWordsOrStemAndReturnVocabulary(df_test, "title", target_col = "Tokenized Title", remove_stop_words = False, with_stemming = False, window = [1,2])

df_train, vocabularyContent = tokenizeAndRemoveStopWordsOrStemAndReturnVocabulary(df_train, "content", target_col = "Tokenized Description", remove_stop_words = False, with_stemming = False, window = [1,2])
df_test, _ = tokenizeAndRemoveStopWordsOrStemAndReturnVocabulary(df_test, "content", target_col = "Tokenized Description", remove_stop_words = False, with_stemming = False, window = [1,2])

# %%
df_train.head()
# Out:
#    label                              title  \
# 0      3                          Ernie Cox
# 1     10                          Holosteum
# 2      9                Pestarella tyrrhena
# 3      1          MidSun Junior High School
# 4      6  St James' Church Wrightington Bar
#
#                                              content  \
# 0   Ernest Ernie Cox (February 17 1894 – February...
# 1   Holosteum is a genus of plants in the Pink fa...
# 2   Pestarella tyrrhena (formerly Callianassa tyr...
# 3   MidSun Junior High School is a Canadian middl...
# 4   St James' Church Wrightington Bar is in Churc...
#
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...
# 1  [holosteum, is, a, genus, of, plants, in, the,...
# 2  [pestarella, tyrrhena, (formerly, callianassa,...
# 3  [midsun, junior, high, school, is, a, canadian...
# 4  [st, james', church, wrightington, bar, is, in...

# %%
trainingData, testingData = getTrainingAndTestingData2(df_train, df_test, target_field1 = "Tokenized Title", target_field2 = "Tokenized Description")

# adding new features - "Text Length"
trainingData["Description Length"] = trainingData["Tokenized Description"].apply(len)
trainingData["Title Length"] = trainingData["Tokenized Title"].apply(len)

testingData["Description Length"] = testingData["Tokenized Description"].apply(len)
testingData["Title Length"] = testingData["Tokenized Title"].apply(len)

print("after transformation")
trainingData.head()
# Out:
# Training Data Sample:
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9
# 3  [midsun, junior, high, school, is, a, canadian...            1
# 4  [st, james', church, wrightington, bar, is, in...            6
#
# Testing Data Sample:
#                                      Tokenized Title  \
# 0                      [lajos, drahos, lajos drahos]
# 1  [uss, huntsville, (1857), uss huntsville, hunt...
# 2                                           [scafco]
# 3              [mclean's, mansion, mclean's mansion]
# 4  [avioane, craiova, iar-93, vultur, avioane cra...
#
#                                Tokenized Description  Class Index
# 0  [lajos, drahos, (7, march, 1895, -, 2, june, 1...            4
# 1  [uss, huntsville, was, a, steamer, acquired, b...            5
# 2  [founded, in, 1954, by, ben, g., stone, scafco...            0
# 3  [mclean's, mansion, (originally, holly, lea), ...            6
# 4  [the, avioane, craiova, iar-93, vultur, (eagle...            5
# after transformation
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index  \
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9
# 3  [midsun, junior, high, school, is, a, canadian...            1
# 4  [st, james', church, wrightington, bar, is, in...            6
#
#    Description Length  Title Length
# 0                 127             3
# 1                 107             1
# 2                 133             3
# 3                 153             7
# 4                  81             9

# %%
results = {}

model = NaiveBayesCustom()
modelName = "taking token length of description and title separately"
print(f"--------{modelName}---------")
results[modelName] = run_model2(model, vocabularyTitle, vocabularyContent, trainingData, testingData, smoothening = 1.0, 
                                text_col1 = "Tokenized Title", 
                                text_col2 = "Tokenized Description",
                                new_feature_cols = ["Title Length", "Description Length"]
                               )
# Out:
# --------taking token length of description and title separately---------
# Training with 14 classes, 140000 examples.
# Title vocab size: 309323, Content vocab size: 2405125
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 309323)
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 2405125)
# Predictions added to column 'Predicted'.
# Evaluating on train data...
# Evaluating on 140000 examples
# Overall Accuracy: 99.26%
#
# Class 0 -> Precision: 0.9914, Recall: 0.9770, F1-Score: 0.9841
# Class 1 -> Precision: 0.9863, Recall: 0.9964, F1-Score: 0.9913
# Class 2 -> Precision: 0.9938, Recall: 0.9879, F1-Score: 0.9908
# Class 3 -> Precision: 0.9936, Recall: 0.9972, F1-Score: 0.9954
# Class 4 -> Precision: 0.9914, Recall: 0.9957, F1-Score: 0.9936
# Class 5 -> Precision: 0.9942, Recall: 0.9971, F1-Score: 0.9957
# Class 6 -> Precision: 0.9821, Recall: 0.9910, F1-Score: 0.9865
# Class 7 -> Precision: 0.9901, Recall: 0.9980, F1-Score: 0.9940
# Class 8 -> Precision: 0.9998, Recall: 0.9822, F1-Score: 0.9909
# Class 9 -> Precision: 0.9993, Recall: 0.9883, F1-Score: 0.9938
# Class 10 -> Precision: 0.9956, Recall: 0.9971, F1-Score: 0.9964
# Class 11 -> Precision: 0.9919, Recall: 0.9986, F1-Score: 0.9952
# Class 12 -> Precision: 0.9970, Recall: 0.9952, F1-Score: 0.9961
# Class 13 -> Precision: 0.9903, Recall: 0.9947, F1-Score: 0.9925
#
# Macro-Average F1 Score: 0.9926
# Overall Precision: 0.9926
# Overall Recall: 0.9926
# Overall F1 Score: 0.9926
# Predictions added to column 'Predicted'.
# Evaluating on test data...
# Evaluating on 35000 examples
# Overall Accuracy: 96.92%
#
# Class 0 -> Precision: 0.9648, Recall: 0.9108, F1-Score: 0.9370
# Class 1 -> Precision: 0.9630, Recall: 0.9896, F1-Score: 0.9761
# Class 2 -> Precision: 0.9709, Recall: 0.9216, F1-Score: 0.9456
# Class 3 -> Precision: 0.9813, Recall: 0.9860, F1-Score: 0.9836
# Class 4 -> Precision: 0.9554, Recall: 0.9856, F1-Score: 0.9703
# Class 5 -> Precision: 0.9751, Recall: 0.9888, F1-Score: 0.9819
# Class 6 -> Precision: 0.9518, Recall: 0.9708, F1-Score: 0.9612
# Class 7 -> Precision: 0.9728, Recall: 0.9876, F1-Score: 0.9802
# Class 8 -> Precision: 0.9996, Recall: 0.9588, F1-Score: 0.9788
# Class 9 -> Precision: 0.9958, Recall: 0.9372, F1-Score: 0.9656
# Class 10 -> Precision: 0.9559, Recall: 0.9888, F1-Score: 0.9721
# Class 11 -> Precision: 0.9689, Recall: 0.9956, F1-Score: 0.9820
# Class 12 -> Precision: 0.9816, Recall: 0.9792, F1-Score: 0.9804
# Class 13 -> Precision: 0.9373, Recall: 0.9688, F1-Score: 0.9528
#
# Macro-Average F1 Score: 0.9691
# Overall Precision: 0.9692
# Overall Recall: 0.9692
# Overall F1 Score: 0.9692

# %%
trainingData, testingData = getTrainingAndTestingData2(df_train, df_test, target_field1 = "Tokenized Title", target_field2 = "Tokenized Description")

# adding new features - "Text Length"
trainingData["Avg Length"] = (trainingData["Tokenized Description"].apply(len) + trainingData["Tokenized Title"].apply(len))/2
testingData["Avg Length"] = (testingData["Tokenized Description"].apply(len) + testingData["Tokenized Title"].apply(len))/2

print("after transformation")
print(trainingData.head())

model = NaiveBayesCustom()
modelName = "taking avg token length of description and title"
print(f"--------{modelName}---------")
results[modelName] = run_model2(model, vocabularyTitle, vocabularyContent, trainingData, testingData, smoothening = 1.0, 
                                text_col1 = "Tokenized Title", 
                                text_col2 = "Tokenized Description",
                                new_feature_cols = ["Avg Length"]
                               )
# Out:
# Training Data Sample:
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9
# 3  [midsun, junior, high, school, is, a, canadian...            1
# 4  [st, james', church, wrightington, bar, is, in...            6
#
# Testing Data Sample:
#                                      Tokenized Title  \
# 0                      [lajos, drahos, lajos drahos]
# 1  [uss, huntsville, (1857), uss huntsville, hunt...
# 2                                           [scafco]
# 3              [mclean's, mansion, mclean's mansion]
# 4  [avioane, craiova, iar-93, vultur, avioane cra...
#
#                                Tokenized Description  Class Index
# 0  [lajos, drahos, (7, march, 1895, -, 2, june, 1...            4
# 1  [uss, huntsville, was, a, steamer, acquired, b...            5
# 2  [founded, in, 1954, by, ben, g., stone, scafco...            0
# 3  [mclean's, mansion, (originally, holly, lea), ...            6
# 4  [the, avioane, craiova, iar-93, vultur, (eagle...            5
# after transformation
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index  Avg Length
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3        65.0
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10        54.0
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9        68.0
# 3  [midsun, junior, high, school, is, a, canadian...            1        80.0
# 4  [st, james', church, wrightington, bar, is, in...            6        45.0
# --------taking avg token length of description and title---------
# Training with 14 classes, 140000 examples.
# Title vocab size: 309323, Content vocab size: 2405125
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 309323)
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 2405125)
# Predictions added to column 'Predicted'.
# Evaluating on train data...
# Evaluating on 140000 examples
# Overall Accuracy: 99.26%
#
# Class 0 -> Precision: 0.9913, Recall: 0.9774, F1-Score: 0.9843
# Class 1 -> Precision: 0.9864, Recall: 0.9966, F1-Score: 0.9915
# Class 2 -> Precision: 0.9939, Recall: 0.9875, F1-Score: 0.9907
# Class 3 -> Precision: 0.9935, Recall: 0.9971, F1-Score: 0.9953
# Class 4 -> Precision: 0.9917, Recall: 0.9957, F1-Score: 0.9937
# Class 5 -> Precision: 0.9941, Recall: 0.9972, F1-Score: 0.9957
# Class 6 -> Precision: 0.9819, Recall: 0.9910, F1-Score: 0.9864
# Class 7 -> Precision: 0.9903, Recall: 0.9980, F1-Score: 0.9941
# Class 8 -> Precision: 0.9998, Recall: 0.9818, F1-Score: 0.9907
# Class 9 -> Precision: 0.9993, Recall: 0.9881, F1-Score: 0.9937
# Class 10 -> Precision: 0.9955, Recall: 0.9974, F1-Score: 0.9965
# Class 11 -> Precision: 0.9915, Recall: 0.9986, F1-Score: 0.9950
# Class 12 -> Precision: 0.9971, Recall: 0.9953, F1-Score: 0.9962
# Class 13 -> Precision: 0.9907, Recall: 0.9949, F1-Score: 0.9928
#
# Macro-Average F1 Score: 0.9926
# Overall Precision: 0.9926
# Overall Recall: 0.9926
# Overall F1 Score: 0.9926
# Predictions added to column 'Predicted'.
# Evaluating on test data...
# Evaluating on 35000 examples
# Overall Accuracy: 96.89%
#
# Class 0 -> Precision: 0.9657, Recall: 0.9116, F1-Score: 0.9379
# Class 1 -> Precision: 0.9619, Recall: 0.9884, F1-Score: 0.9749
# Class 2 -> Precision: 0.9701, Recall: 0.9208, F1-Score: 0.9448
# Class 3 -> Precision: 0.9813, Recall: 0.9860, F1-Score: 0.9836
# Class 4 -> Precision: 0.9558, Recall: 0.9856, F1-Score: 0.9705
# Class 5 -> Precision: 0.9744, Recall: 0.9888, F1-Score: 0.9815
# Class 6 -> Precision: 0.9499, Recall: 0.9708, F1-Score: 0.9602
# Class 7 -> Precision: 0.9717, Recall: 0.9872, F1-Score: 0.9794
# Class 8 -> Precision: 0.9996, Recall: 0.9568, F1-Score: 0.9777
# Class 9 -> Precision: 0.9957, Recall: 0.9360, F1-Score: 0.9649
# Class 10 -> Precision: 0.9556, Recall: 0.9892, F1-Score: 0.9721
# Class 11 -> Precision: 0.9692, Recall: 0.9956, F1-Score: 0.9822
# Class 12 -> Precision: 0.9816, Recall: 0.9796, F1-Score: 0.9806
# Class 13 -> Precision: 0.9376, Recall: 0.9684, F1-Score: 0.9528
#
# Macro-Average F1 Score: 0.9688
# Overall Precision: 0.9689
# Overall Recall: 0.9689
# Overall F1 Score: 0.9689

# %%
trainingData, testingData = getTrainingAndTestingData2(df_train, df_test, target_field1 = "Tokenized Title", target_field2 = "Tokenized Description")

# adding new features - "Text Length"
trainingData["Description Length"] = df_train["content"].apply(len)
trainingData["Title Length"] = df_train["title"].apply(len)

testingData["Description Length"] = df_test["content"].apply(len)
testingData["Title Length"] = df_test["title"].apply(len)
print("after transformation")
print(trainingData.head())

model = NaiveBayesCustom()
modelName = "taking string length of description and title separately"
print(f"--------{modelName}---------")
results[modelName] = run_model2(model, vocabularyTitle, vocabularyContent, trainingData, testingData, smoothening = 1.0, 
                                text_col1 = "Tokenized Title", 
                                text_col2 = "Tokenized Description",
                                new_feature_cols = ["Description Length", "Title Length"]
                               )
# Out:
# Training Data Sample:
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9
# 3  [midsun, junior, high, school, is, a, canadian...            1
# 4  [st, james', church, wrightington, bar, is, in...            6
#
# Testing Data Sample:
#                                      Tokenized Title  \
# 0                      [lajos, drahos, lajos drahos]
# 1  [uss, huntsville, (1857), uss huntsville, hunt...
# 2                                           [scafco]
# 3              [mclean's, mansion, mclean's mansion]
# 4  [avioane, craiova, iar-93, vultur, avioane cra...
#
#                                Tokenized Description  Class Index
# 0  [lajos, drahos, (7, march, 1895, -, 2, june, 1...            4
# 1  [uss, huntsville, was, a, steamer, acquired, b...            5
# 2  [founded, in, 1954, by, ben, g., stone, scafco...            0
# 3  [mclean's, mansion, (originally, holly, lea), ...            6
# 4  [the, avioane, craiova, iar-93, vultur, (eagle...            5
# after transformation
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index  \
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9
# 3  [midsun, junior, high, school, is, a, canadian...            1
# 4  [st, james', church, wrightington, bar, is, in...            6
#
#    Description Length  Title Length
# 0                 355             9
# 1                 312             9
# 2                 399            19
# 3                 465            25
# 4                 244            33
# --------taking string length of description and title separately---------
# Training with 14 classes, 140000 examples.
# Title vocab size: 309323, Content vocab size: 2405125
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 309323)
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 2405125)
# Predictions added to column 'Predicted'.
# Evaluating on train data...
# Evaluating on 140000 examples
# Overall Accuracy: 99.27%
#
# Class 0 -> Precision: 0.9915, Recall: 0.9775, F1-Score: 0.9844
# Class 1 -> Precision: 0.9866, Recall: 0.9965, F1-Score: 0.9915
# Class 2 -> Precision: 0.9940, Recall: 0.9878, F1-Score: 0.9909
# Class 3 -> Precision: 0.9935, Recall: 0.9973, F1-Score: 0.9954
# Class 4 -> Precision: 0.9913, Recall: 0.9958, F1-Score: 0.9936
# Class 5 -> Precision: 0.9942, Recall: 0.9971, F1-Score: 0.9957
# Class 6 -> Precision: 0.9820, Recall: 0.9911, F1-Score: 0.9865
# Class 7 -> Precision: 0.9901, Recall: 0.9980, F1-Score: 0.9940
# Class 8 -> Precision: 0.9998, Recall: 0.9820, F1-Score: 0.9908
# Class 9 -> Precision: 0.9994, Recall: 0.9881, F1-Score: 0.9937
# Class 10 -> Precision: 0.9955, Recall: 0.9974, F1-Score: 0.9965
# Class 11 -> Precision: 0.9917, Recall: 0.9987, F1-Score: 0.9952
# Class 12 -> Precision: 0.9971, Recall: 0.9951, F1-Score: 0.9961
# Class 13 -> Precision: 0.9909, Recall: 0.9948, F1-Score: 0.9929
#
# Macro-Average F1 Score: 0.9927
# Overall Precision: 0.9927
# Overall Recall: 0.9927
# Overall F1 Score: 0.9927
# Predictions added to column 'Predicted'.
# Evaluating on test data...
# Evaluating on 35000 examples
# Overall Accuracy: 96.91%
#
# Class 0 -> Precision: 0.9653, Recall: 0.9116, F1-Score: 0.9377
# Class 1 -> Precision: 0.9626, Recall: 0.9896, F1-Score: 0.9759
# Class 2 -> Precision: 0.9705, Recall: 0.9208, F1-Score: 0.9450
# Class 3 -> Precision: 0.9813, Recall: 0.9860, F1-Score: 0.9836
# Class 4 -> Precision: 0.9558, Recall: 0.9852, F1-Score: 0.9703
# Class 5 -> Precision: 0.9744, Recall: 0.9888, F1-Score: 0.9815
# Class 6 -> Precision: 0.9514, Recall: 0.9700, F1-Score: 0.9606
# Class 7 -> Precision: 0.9728, Recall: 0.9876, F1-Score: 0.9802
# Class 8 -> Precision: 0.9996, Recall: 0.9588, F1-Score: 0.9788
# Class 9 -> Precision: 0.9957, Recall: 0.9364, F1-Score: 0.9652
# Class 10 -> Precision: 0.9552, Recall: 0.9892, F1-Score: 0.9719
# Class 11 -> Precision: 0.9692, Recall: 0.9956, F1-Score: 0.9822
# Class 12 -> Precision: 0.9816, Recall: 0.9792, F1-Score: 0.9804
# Class 13 -> Precision: 0.9373, Recall: 0.9688, F1-Score: 0.9528
#
# Macro-Average F1 Score: 0.9690
# Overall Precision: 0.9691
# Overall Recall: 0.9691
# Overall F1 Score: 0.9691

# %%
trainingData, testingData = getTrainingAndTestingData2(df_train, df_test, target_field1 = "Tokenized Title", target_field2 = "Tokenized Description")

# adding new features - "Text Length"
trainingData["Avg Length"] = (df_train["content"].apply(len) + df_train["title"].apply(len))/2

testingData["Avg Length"] = (df_test["content"].apply(len) + df_test["title"].apply(len))/2
print("after transformation")
print(trainingData.head())

model = NaiveBayesCustom()
modelName = "taking avg string length of description and title"
print(f"--------{modelName}---------")
results[modelName] = run_model2(model, vocabularyTitle, vocabularyContent, trainingData, testingData, smoothening = 1.0, 
                                text_col1 = "Tokenized Title", 
                                text_col2 = "Tokenized Description",
                                new_feature_cols = ["Avg Length"]
                               )
# Out:
# Training Data Sample:
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9
# 3  [midsun, junior, high, school, is, a, canadian...            1
# 4  [st, james', church, wrightington, bar, is, in...            6
#
# Testing Data Sample:
#                                      Tokenized Title  \
# 0                      [lajos, drahos, lajos drahos]
# 1  [uss, huntsville, (1857), uss huntsville, hunt...
# 2                                           [scafco]
# 3              [mclean's, mansion, mclean's mansion]
# 4  [avioane, craiova, iar-93, vultur, avioane cra...
#
#                                Tokenized Description  Class Index
# 0  [lajos, drahos, (7, march, 1895, -, 2, june, 1...            4
# 1  [uss, huntsville, was, a, steamer, acquired, b...            5
# 2  [founded, in, 1954, by, ben, g., stone, scafco...            0
# 3  [mclean's, mansion, (originally, holly, lea), ...            6
# 4  [the, avioane, craiova, iar-93, vultur, (eagle...            5
# after transformation
#                                      Tokenized Title  \
# 0                            [ernie, cox, ernie cox]
# 1                                        [holosteum]
# 2        [pestarella, tyrrhena, pestarella tyrrhena]
# 3  [midsun, junior, high, school, midsun junior, ...
# 4  [st, james', church, wrightington, bar, st jam...
#
#                                Tokenized Description  Class Index  Avg Length
# 0  [ernest, ernie, cox, (february, 17, 1894, –, f...            3       182.0
# 1  [holosteum, is, a, genus, of, plants, in, the,...           10       160.5
# 2  [pestarella, tyrrhena, (formerly, callianassa,...            9       209.0
# 3  [midsun, junior, high, school, is, a, canadian...            1       245.0
# 4  [st, james', church, wrightington, bar, is, in...            6       138.5
# --------taking avg string length of description and title---------
# Training with 14 classes, 140000 examples.
# Title vocab size: 309323, Content vocab size: 2405125
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 309323)
# Shape of phi_y: (14,)
# Shape of phi_j_given_y: (14, 2405125)
# Predictions added to column 'Predicted'.
# Evaluating on train data...
# Evaluating on 140000 examples
# Overall Accuracy: 99.26%
#
# Class 0 -> Precision: 0.9915, Recall: 0.9774, F1-Score: 0.9844
# Class 1 -> Precision: 0.9863, Recall: 0.9965, F1-Score: 0.9914
# Class 2 -> Precision: 0.9939, Recall: 0.9875, F1-Score: 0.9907
# Class 3 -> Precision: 0.9935, Recall: 0.9971, F1-Score: 0.9953
# Class 4 -> Precision: 0.9916, Recall: 0.9958, F1-Score: 0.9937
# Class 5 -> Precision: 0.9942, Recall: 0.9972, F1-Score: 0.9957
# Class 6 -> Precision: 0.9819, Recall: 0.9909, F1-Score: 0.9864
# Class 7 -> Precision: 0.9903, Recall: 0.9980, F1-Score: 0.9941
# Class 8 -> Precision: 0.9998, Recall: 0.9819, F1-Score: 0.9908
# Class 9 -> Precision: 0.9993, Recall: 0.9881, F1-Score: 0.9937
# Class 10 -> Precision: 0.9955, Recall: 0.9974, F1-Score: 0.9965
# Class 11 -> Precision: 0.9915, Recall: 0.9986, F1-Score: 0.9950
# Class 12 -> Precision: 0.9971, Recall: 0.9953, F1-Score: 0.9962
# Class 13 -> Precision: 0.9907, Recall: 0.9950, F1-Score: 0.9929
#
# Macro-Average F1 Score: 0.9926
# Overall Precision: 0.9926
# Overall Recall: 0.9926
# Overall F1 Score: 0.9926
# Predictions added to column 'Predicted'.
# Evaluating on test data...
# Evaluating on 35000 examples
# Overall Accuracy: 96.89%
#
# Class 0 -> Precision: 0.9653, Recall: 0.9116, F1-Score: 0.9377
# Class 1 -> Precision: 0.9619, Recall: 0.9884, F1-Score: 0.9749
# Class 2 -> Precision: 0.9701, Recall: 0.9204, F1-Score: 0.9446
# Class 3 -> Precision: 0.9813, Recall: 0.9860, F1-Score: 0.9836
# Class 4 -> Precision: 0.9558, Recall: 0.9856, F1-Score: 0.9705
# Class 5 -> Precision: 0.9744, Recall: 0.9888, F1-Score: 0.9815
# Class 6 -> Precision: 0.9499, Recall: 0.9708, F1-Score: 0.9602
# Class 7 -> Precision: 0.9717, Recall: 0.9872, F1-Score: 0.9794
# Class 8 -> Precision: 0.9996, Recall: 0.9568, F1-Score: 0.9777
# Class 9 -> Precision: 0.9957, Recall: 0.9364, F1-Score: 0.9652
# Class 10 -> Precision: 0.9556, Recall: 0.9892, F1-Score: 0.9721
# Class 11 -> Precision: 0.9692, Recall: 0.9956, F1-Score: 0.9822
# Class 12 -> Precision: 0.9816, Recall: 0.9796, F1-Score: 0.9806
# Class 13 -> Precision: 0.9376, Recall: 0.9680, F1-Score: 0.9526
#
# Macro-Average F1 Score: 0.9688
# Overall Precision: 0.9689
# Overall Recall: 0.9689
# Overall F1 Score: 0.9689

# %%
display_results_table(results)
# Out:
# ==========================================================================================
# Model: taking token length of description and title separately
# ==========================================================================================
# ╒══════════════════════╤═════════╤═════════╕
# │ Metric               │   Train │    Test │
# ╞══════════════════════╪═════════╪═════════╡
# │ Overall Accuracy (%) │ 99.26   │ 96.92   │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Precision    │  0.9926 │  0.9692 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Recall       │  0.9926 │  0.9692 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall F1 Score     │  0.9926 │  0.9692 │
# ├──────────────────────┼─────────┼─────────┤
# │ Macro F1 Score       │  0.9926 │  0.9691 │
# ╘══════════════════════╧═════════╧═════════╛
#
# ==========================================================================================
# Model: taking avg token length of description and title
# ==========================================================================================
# ╒══════════════════════╤═════════╤═════════╕
# │ Metric               │   Train │    Test │
# ╞══════════════════════╪═════════╪═════════╡
# │ Overall Accuracy (%) │ 99.26   │ 96.89   │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Precision    │  0.9926 │  0.9689 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Recall       │  0.9926 │  0.9689 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall F1 Score     │  0.9926 │  0.9689 │
# ├──────────────────────┼─────────┼─────────┤
# │ Macro F1 Score       │  0.9926 │  0.9688 │
# ╘══════════════════════╧═════════╧═════════╛
#
# ==========================================================================================
# Model: taking string length of description and title separately
# ==========================================================================================
# ╒══════════════════════╤═════════╤═════════╕
# │ Metric               │   Train │    Test │
# ╞══════════════════════╪═════════╪═════════╡
# │ Overall Accuracy (%) │ 99.27   │ 96.91   │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Precision    │  0.9927 │  0.9691 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Recall       │  0.9927 │  0.9691 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall F1 Score     │  0.9927 │  0.9691 │
# ├──────────────────────┼─────────┼─────────┤
# │ Macro F1 Score       │  0.9927 │  0.969  │
# ╘══════════════════════╧═════════╧═════════╛
#
# ==========================================================================================
# Model: taking avg string length of description and title
# ==========================================================================================
# ╒══════════════════════╤═════════╤═════════╕
# │ Metric               │   Train │    Test │
# ╞══════════════════════╪═════════╪═════════╡
# │ Overall Accuracy (%) │ 99.26   │ 96.89   │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Precision    │  0.9926 │  0.9689 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall Recall       │  0.9926 │  0.9689 │
# ├──────────────────────┼─────────┼─────────┤
# │ Overall F1 Score     │  0.9926 │  0.9689 │
# ├──────────────────────┼─────────┼─────────┤
# │ Macro F1 Score       │  0.9926 │  0.9688 │
# ╘══════════════════════╧═════════╧═════════╛
